# %%
import pandas as pd
import numpy as np

df = pd.read_csv("https://raw.githubusercontent.com/lifeonthefence/text-success/main/Data/Ukraine%20Tweets.csv")

# %%
df.head()
# Out:
#                     id                       date             user  \
# 0  1477420789863436289  2022-01-01 23:25:40+00:00         anno1540
# 1  1477414596424220679  2022-01-01 23:01:03+00:00   weather_odessa
# 2  1477414332376010752  2022-01-01 23:00:00+00:00    AlArabiya_Eng
# 3  1477409748572151809  2022-01-01 22:41:47+00:00    beatravelling
# 4  1477409332820119552  2022-01-01 22:40:08+00:00  TornCurtain1991
#
#    user_followers               user_created  \
# 0            8838  2014-06-12 17:05:22+00:00
# 1             119  2019-07-10 08:34:22+00:00
# 2          927174  2009-02-28 08:31:32+00:00
# 3            6329  2014-02-28 21:25:33+00:00
# 4             677  2012-02-08 15:30:41+00:00
#
#                                     rendered_content  likes  retweets  \
# 0  Lithuania will never abandon Ukraine, voluntee...      5         1
# 1  #odessa #odesa #ukraine #одесса\nNow: 4.2°C\nT...      0         0
# 2  After tough talk between Presidents Joe Biden ...      4         0
# ...

# %%
pip install py-readability-metrics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.set_index('id').to_dict()['rendered_content']
# Out:
# {1477420789863436289: 'Lithuania will never abandon Ukraine, volunteer helping Ukrainian army says\n\n#Lithuania #Ukraine\neuromaidanpress.com/2021/12/29/lit…',
#  1477414596424220679: "#odessa #odesa #ukraine #одесса\nNow: 4.2°C\nToday's Min: 4.2°C at 00:28:52\nToday's Max: 4.4°C at 00:00:00\nMonth's Min: 2.9°C at 2022-01-01 00:00:00\nMonth's Max: 6.9°C at 2022-01-01 11:35:31",
#  1477414332376010752: "After tough talk between Presidents Joe Biden and Vladimir Putin over #Russia's troop buildup on the #Ukraine border, both sides insist they are hopeful that a pathway to easing tensions could open during diplomatic talks set for January.\n\nenglish.alarabiya.net/News/world/202…",
#  1477409748572151809: 'The beach can be nice in the fall too 😊🇺🇦\n\n#lanzheron #langeron #beach #odessa #ukraine\n\nbeatravelling.com/2022/01/01/lan…',
# ...

# %%
dictionary_content = df.set_index("rendered_content")

# %%
from readability import Readability

r = Readability(dictionary_content)

r.flesch_kincaid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/fk/81vm3qzx55z_4v1mpq7r9xm40000gn/T/ipykernel_54652/2005170465.py in <module>
#       1 from readability import Readability
#       2
# ----> 3 r = Readability(dictionary_content)
#       4
#       5 r.flesch_kincaid()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/readability/readability.py in __init__(self, text)
#       7     def __init__(self, text):
#       8         self._analyzer = Analyzer()
# ----> 9         self._statistics = self._analyzer.analyze(text)
#      10
#      11     def ari(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/readability/text/analyzer.py in analyze(self, text)
#      63         self._dale_chall_set = self._load_dale_chall()
#      64         self._spache_set = self._load_spache()
# ---> 65         stats = self._statistics(text)
# ...

# %%
pip install NLP-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from NLP import NLP
nlp = NLP()

# %%
 df.rendered_content.values.tolist()
# Out:
# ['Lithuania will never abandon Ukraine, volunteer helping Ukrainian army says\n\n#Lithuania #Ukraine\neuromaidanpress.com/2021/12/29/lit…',
#  "#odessa #odesa #ukraine #одесса\nNow: 4.2°C\nToday's Min: 4.2°C at 00:28:52\nToday's Max: 4.4°C at 00:00:00\nMonth's Min: 2.9°C at 2022-01-01 00:00:00\nMonth's Max: 6.9°C at 2022-01-01 11:35:31",
#  "After tough talk between Presidents Joe Biden and Vladimir Putin over #Russia's troop buildup on the #Ukraine border, both sides insist they are hopeful that a pathway to easing tensions could open during diplomatic talks set for January.\n\nenglish.alarabiya.net/News/world/202…",
#  'The beach can be nice in the fall too 😊🇺🇦\n\n#lanzheron #langeron #beach #odessa #ukraine\n\nbeatravelling.com/2022/01/01/lan…',
# ...

# %%
list_content = df.rendered_content.values.tolist()
