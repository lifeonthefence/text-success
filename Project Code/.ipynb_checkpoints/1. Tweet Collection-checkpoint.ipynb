# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from datetime import datetime, timedelta
import time

# %%
# Set search parameters
keyword = 'ukraine'
hashtag = ['#ukraine']#, '#ukrainewar', '#UkraineRussiaWar️']#, '#putinwarcriminal', '#zelenskywarcriminal', '#standwithrussia', '#istandwithrussia', '#StandWithUkraine', '#IStandWithUkraine']
start_date = datetime(2022, 1, 1)
end_date = datetime(2022, 12, 31)
delta = timedelta(days=1)

lang_code = "en"
follower_threshold = 100
tweet_limit = 100

# %%
t0 = time.time()
tweets = []

while start_date <= end_date:
    for tag in hashtag:
        query = f'{tag} lang:{lang_code} since:{start_date.date()} until:{(start_date + delta).date()} exclude:retweets exclude:replies'
        for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
            if tweet.user.followersCount >= follower_threshold:
                tweets.append({
                    'id': tweet.id,
                    'date': tweet.date,
                    'user': tweet.user.username,
                    'user_followers': tweet.user.followersCount,
                    'user_created': tweet.user.created,
                    'rendered_content': tweet.renderedContent,
                    'likes': tweet.likeCount,
                    'retweets': tweet.retweetCount,
                    'replies': tweet.replyCount,
                    'quoteCount': tweet.quoteCount,
                    'hashtags': tweet.hashtags,
                    'lang': tweet.lang,
                    'media': tweet.media,
                    'mentionedUsers': tweet.mentionedUsers,
                })
            if i >= tweet_limit:
                break
    start_date += delta
    
t1 = time.time()
print(round(t1 - t0), "seconds")
# Out:
# 4780 seconds

# %%
df = pd.DataFrame(tweets)
len(df)
# Out:
# 60133

# %%
df.head()
# Out:
#                     id                      date             user  \
# 0  1477420789863436289 2022-01-01 23:25:40+00:00         anno1540
# 1  1477414596424220679 2022-01-01 23:01:03+00:00   weather_odessa
# 2  1477414332376010752 2022-01-01 23:00:00+00:00    AlArabiya_Eng
# 3  1477409748572151809 2022-01-01 22:41:47+00:00    beatravelling
# 4  1477409332820119552 2022-01-01 22:40:08+00:00  TornCurtain1991
#
#    user_followers              user_created  \
# 0            8838 2014-06-12 17:05:22+00:00
# 1             119 2019-07-10 08:34:22+00:00
# 2          927174 2009-02-28 08:31:32+00:00
# 3            6329 2014-02-28 21:25:33+00:00
# 4             677 2012-02-08 15:30:41+00:00
#
#                                     rendered_content  likes  retweets  \
# 0  Lithuania will never abandon Ukraine, voluntee...      5         1
# 1  #odessa #odesa #ukraine #одесса\nNow: 4.2°C\nT...      0         0
# 2  After tough talk between Presidents Joe Biden ...      4         0
# ...

# %%
df.to_csv("Ukraine Tweets Unlimited.csv", index = False)
